# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib. pylab as plt
import warnings
warnings.filterwarnings("ignore")

# %%
df = pd. read_csv("E:\LiveProject\Job Placement\Job_Placement_Data.csv")

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 215 entries, 0 to 214
# Data columns (total 13 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   gender               215 non-null    object
#  1   ssc_percentage       215 non-null    float64
#  2   ssc_board            215 non-null    object
#  3   hsc_percentage       215 non-null    float64
#  4   hsc_board            215 non-null    object
#  5   hsc_subject          215 non-null    object
#  6   degree_percentage    215 non-null    float64
#  7   undergrad_degree     215 non-null    object
#  8   work_experience      215 non-null    object
#  9   emp_test_percentage  215 non-null    float64
#  10  specialisation       215 non-null    object
#  11  mba_percent          215 non-null    float64
#  12  status               215 non-null    object
# dtypes: float64(5), object(8)
# memory usage: 22.0+ KB

# %%
df. dtypes
# Out:
# gender                  object
# ssc_percentage         float64
# ssc_board               object
# hsc_percentage         float64
# hsc_board               object
# hsc_subject             object
# degree_percentage      float64
# undergrad_degree        object
# work_experience         object
# emp_test_percentage    float64
# specialisation          object
# mba_percent            float64
# status                  object
# dtype: object

# %%
df. shape
# Out:
# (215, 13)

# %%
df. head()
# Out:
#   gender  ssc_percentage ssc_board  hsc_percentage hsc_board hsc_subject  \
# 0      M           67.00    Others           91.00    Others    Commerce
# 1      M           79.33   Central           78.33    Others     Science
# 2      M           65.00   Central           68.00   Central        Arts
# 3      M           56.00   Central           52.00   Central     Science
# 4      M           85.80   Central           73.60   Central    Commerce
#
#    degree_percentage undergrad_degree work_experience  emp_test_percentage  \
# 0              58.00         Sci&Tech              No                 55.0
# 1              77.48         Sci&Tech             Yes                 86.5
# 2              64.00        Comm&Mgmt              No                 75.0
# 3              52.00         Sci&Tech              No                 66.0
# 4              73.30        Comm&Mgmt              No                 96.8
#
#   specialisation  mba_percent      status
# ...

# %%
df. duplicated(). sum()
# Out:
# 0

# %%
df. isna(). sum()
# Out:
# gender                 0
# ssc_percentage         0
# ssc_board              0
# hsc_percentage         0
# hsc_board              0
# hsc_subject            0
# degree_percentage      0
# undergrad_degree       0
# work_experience        0
# emp_test_percentage    0
# specialisation         0
# mba_percent            0
# status                 0
# dtype: int64

# %%
df. gender. value_counts()
# Out:
# M    139
# F     76
# Name: gender, dtype: int64

# %%
sns. countplot(x = df["gender"])
# Out:
# <AxesSubplot: xlabel='gender', ylabel='count'>

# %%
df. ssc_board. value_counts()
# Out:
# Central    116
# Others      99
# Name: ssc_board, dtype: int64

# %%
sns. countplot(x = df["ssc_board"])
# Out:
# <AxesSubplot: xlabel='ssc_board', ylabel='count'>

# %%
df. hsc_board. value_counts()
# Out:
# Others     131
# Central     84
# Name: hsc_board, dtype: int64

# %%
sns. countplot(x = df["hsc_board"])
# Out:
# <AxesSubplot: xlabel='hsc_board', ylabel='count'>

# %%
df. hsc_subject. value_counts()
# Out:
# Commerce    113
# Science      91
# Arts         11
# Name: hsc_subject, dtype: int64

# %%
sns. countplot(y = df["hsc_subject"])
# Out:
# <AxesSubplot: xlabel='count', ylabel='hsc_subject'>

# %%
df. undergrad_degree. value_counts()
# Out:
# Comm&Mgmt    145
# Sci&Tech      59
# Others        11
# Name: undergrad_degree, dtype: int64

# %%
sns. countplot(x = df["undergrad_degree"])
# Out:
# <AxesSubplot: xlabel='undergrad_degree', ylabel='count'>

# %%
df. work_experience. value_counts()
# Out:
# No     141
# Yes     74
# Name: work_experience, dtype: int64

# %%
df. specialisation. value_counts()
# Out:
# Mkt&Fin    120
# Mkt&HR      95
# Name: specialisation, dtype: int64

# %%
df. status. value_counts(normalize = True) # data in balanced
# Out:
# Placed        0.688372
# Not Placed    0.311628
# Name: status, dtype: float64

# %%
plt. hist(df["ssc_percentage"])
# Out:
# (array([ 5.,  7., 22., 19., 43., 32., 29., 26., 22., 10.]),
#  array([40.89 , 45.741, 50.592, 55.443, 60.294, 65.145, 69.996, 74.847,
#         79.698, 84.549, 89.4  ]),
#  <BarContainer object of 10 artists>)

# %%
df. max()
# Out:
# gender                        M
# ssc_percentage             89.4
# ssc_board                Others
# hsc_percentage             97.7
# hsc_board                Others
# hsc_subject             Science
# degree_percentage          91.0
# undergrad_degree       Sci&Tech
# work_experience             Yes
# emp_test_percentage        98.0
# specialisation           Mkt&HR
# mba_percent               77.89
# status                   Placed
# dtype: object

# %%
df. min()
# Out:
# gender                          F
# ssc_percentage              40.89
# ssc_board                 Central
# hsc_percentage               37.0
# hsc_board                 Central
# hsc_subject                  Arts
# degree_percentage            50.0
# undergrad_degree        Comm&Mgmt
# work_experience                No
# emp_test_percentage          50.0
# specialisation            Mkt&Fin
# mba_percent                 51.21
# status                 Not Placed
# dtype: object

# %%
df. mode()
# Out:
#   gender  ssc_percentage ssc_board  hsc_percentage hsc_board hsc_subject  \
# 0      M            62.0   Central            63.0    Others    Commerce
#
#    degree_percentage undergrad_degree work_experience  emp_test_percentage  \
# 0               65.0        Comm&Mgmt              No                 60.0
#
#   specialisation  mba_percent  status
# 0        Mkt&Fin         56.7  Placed

# %%
df. var()
# Out:
# ssc_percentage         117.228377
# hsc_percentage         118.755706
# degree_percentage       54.151103
# emp_test_percentage    176.251018
# mba_percent             34.028376
# dtype: float64

# %%
df. skew(axis = 0, skipna = True) ## skewness value vis close to 0 so here data is normally distributed
# Out:
# ssc_percentage        -0.132649
# hsc_percentage         0.163639
# degree_percentage      0.244917
# emp_test_percentage    0.282308
# mba_percent            0.313576
# dtype: float64

# %%
df. kurtosis(axis = 0, skipna = True)
# Out:
# ssc_percentage        -0.607510
# hsc_percentage         0.450765
# degree_percentage      0.052143
# emp_test_percentage   -1.088580
# mba_percent           -0.470723
# dtype: float64

# %%
import scipy. stats as stats
import pylab

# %%
stats. probplot(df["ssc_percentage"], dist = "norm", plot = pylab); plt. show()
# maximum data has fallen under the line so here data normally distributed

# %%
stats. probplot(df["hsc_percentage"], dist = "norm", plot = pylab); plt. show()
# maximum data has fallen under the line so here data normally distributed

# %%
stats. probplot(df["degree_percentage"], dist = "norm", plot = pylab); plt. show()
# maximum data has fallen under the line so here data normally distributed

# %%
stats. probplot(df["emp_test_percentage"], dist = "norm", plot = pylab); plt. show()
# maximum data has fallen under the line so here data normally distributed

# %%
stats. probplot(df["mba_percent"], dist = "norm", plot = pylab); plt. show()
# maximum data has fallen under the line so here data normally distributed

# %% [markdown]
# # outlier checking

# %%
plt. figure(figsize = (10,6))
sns. boxplot(df)
plt.show()

# %%
# here hsc_percentage and degree_percentage having outliers
from feature_engine.outliers import Winsorizer
winsor = Winsorizer(capping_method = 'iqr',
                   tail = 'both',
                   fold = 1.5,
                   variables = ["hsc_percentage"])
df["hsc_percentage"] = winsor. fit_transform(df[["hsc_percentage"]])

# %%
winsor = Winsorizer(capping_method = 'iqr',
                   tail = 'both',
                   fold = 1.5,
                   variables = ["degree_percentage"])
df["degree_percentage"] = winsor. fit_transform(df[["degree_percentage"]])

# %%
plt. figure(figsize = (5,4))
sns. boxplot(df)
plt.show()

# %%
df. describe()
# Out:
#        ssc_percentage  hsc_percentage  degree_percentage  emp_test_percentage  \
# count      215.000000      215.000000         215.000000           215.000000
# mean        67.303395       66.334744          66.358558            72.100558
# std         10.827205       10.586016           7.321524            13.275956
# min         40.890000       42.750000          50.000000            50.000000
# 25%         60.600000       60.900000          61.000000            60.000000
# 50%         67.000000       65.000000          66.000000            71.000000
# 75%         75.700000       73.000000          72.000000            83.500000
# max         89.400000       91.150000          88.500000            98.000000
#
#        mba_percent
# count   215.000000
# mean     62.278186
# std       5.833385
# min      51.210000
# 25%      57.945000
# 50%      62.000000
# 75%      66.255000
# max      77.890000

# %%
mapping = {'M': 1, 'F': 0}
df['gender'] = df['gender'].map(mapping)

# %%
mapping = {"Central":1, "Others":2}
df['ssc_board'] = df['ssc_board'].map(mapping)

# %%
mapping = {"Central":1, "Others":2}
df['hsc_board'] = df['hsc_board'].map(mapping)

# %%
mapping = {"Commerce":1, "Science":2, "Arts":3}
df['hsc_subject'] = df['hsc_subject'].map(mapping)

# %%
mapping = {"Comm&Mgmt":1, "Sci&Tech":2, "Others":3}
df['undergrad_degree'] = df['undergrad_degree'].map(mapping)

# %%
mapping = {"No":1, "Yes":2}
df['work_experience'] = df['work_experience'].map(mapping)

# %%
mapping = {"Mkt&Fin":1, "Mkt&HR":2}
df['specialisation'] = df['specialisation'].map(mapping)

# %%
mapping = {"Placed":1, "Not Placed":2}
df['status'] = df['status'].map(mapping)

# %%
df. head()
# Out:
#    gender  ssc_percentage  ssc_board  hsc_percentage  hsc_board  hsc_subject  \
# 0       1           67.00          2           91.00          2            1
# 1       1           79.33          1           78.33          2            2
# 2       1           65.00          1           68.00          1            3
# 3       1           56.00          1           52.00          1            2
# 4       1           85.80          1           73.60          1            1
#
#    degree_percentage  undergrad_degree  work_experience  emp_test_percentage  \
# 0              58.00                 2                1                 55.0
# 1              77.48                 2                2                 86.5
# 2              64.00                 1                1                 75.0
# 3              52.00                 2                1                 66.0
# 4              73.30                 1                1                 96.8
#
#    specialisation  mba_percent  status
# ...

# %%
plt. figure(figsize = (18,15))
sns. heatmap(df. corr(), annot = True, fmt = ".2f")
# Out:
# <AxesSubplot: >

# %%
X = df.iloc[:,:-1]

# %%
X. head()
# Out:
#    gender  ssc_percentage  ssc_board  hsc_percentage  hsc_board  hsc_subject  \
# 0       1           67.00          2           91.00          2            1
# 1       1           79.33          1           78.33          2            2
# 2       1           65.00          1           68.00          1            3
# 3       1           56.00          1           52.00          1            2
# 4       1           85.80          1           73.60          1            1
#
#    degree_percentage  undergrad_degree  work_experience  emp_test_percentage  \
# 0              58.00                 2                1                 55.0
# 1              77.48                 2                2                 86.5
# 2              64.00                 1                1                 75.0
# 3              52.00                 2                1                 66.0
# 4              73.30                 1                1                 96.8
#
#    specialisation  mba_percent
# ...

# %%
y = df.iloc[:,-1]

# %%
y. head()
# Out:
# 0    1
# 1    1
# 2    1
# 3    2
# 4    1
# Name: status, dtype: int64

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.2, random_state = 51)

# %%
print("X_train Shape is : ", X_train.shape)
print("X_test Shape is : ", X_test.shape)
print("y_train Shape is : ", y_train.shape)
print("y_test Shape is : ", y_test.shape)
# Out:
# X_train Shape is :  (172, 12)
# X_test Shape is :  (43, 12)
# y_train Shape is :  (172,)
# y_test Shape is :  (43,)

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.naive_bayes import MultinomialNB
from sklearn.naive_bayes import BernoulliNB
from sklearn.neighbors import KNeighborsClassifier
from sklearn.ensemble import GradientBoostingClassifier
from sklearn.ensemble import AdaBoostClassifier
import xgboost as xgb

from sklearn.metrics import accuracy_score, classification_report

# %%
lr = LogisticRegression()
lr.fit(X_train, y_train)
y_test_pred = lr.predict(X_test)
print("Accuracy:" , accuracy_score(y_test, y_test_pred))
print(classification_report(y_test, y_test_pred))
# Out:
# Accuracy: 0.9069767441860465
#               precision    recall  f1-score   support
#
#            1       0.91      0.97      0.94        31
#            2       0.90      0.75      0.82        12
#
#     accuracy                           0.91        43
#    macro avg       0.90      0.86      0.88        43
# weighted avg       0.91      0.91      0.90        43

# %%
y_train_pred = lr.predict(X_train)
print("Accuracy:" , accuracy_score(y_train, y_train_pred))
# Out:
# Accuracy: 0.8895348837209303

# %%
dt = DecisionTreeClassifier(max_depth=8)
dt.fit(X_train, y_train)
y_test_pred = dt.predict(X_test)
print("Accuracy:" , accuracy_score(y_test, y_test_pred))
print(classification_report(y_test, y_test_pred))
# Out:
# Accuracy: 0.7441860465116279
#               precision    recall  f1-score   support
#
#            1       0.83      0.81      0.82        31
#            2       0.54      0.58      0.56        12
#
#     accuracy                           0.74        43
#    macro avg       0.69      0.69      0.69        43
# weighted avg       0.75      0.74      0.75        43

# %%
y_train_pred = dt.predict(X_train)
print("Accuracy:" , accuracy_score(y_train, y_train_pred))
# Out:
# Accuracy: 0.9941860465116279

# %%
rf = RandomForestClassifier(n_estimators=20,
                              random_state=3,
                              max_samples=0.5,
                              max_features=0.75,
                              max_depth=25)
rf.fit(X_train, y_train)
y_test_pred = rf.predict(X_test)
print("Accuracy:" , accuracy_score(y_test, y_test_pred))
print(classification_report(y_test, y_test_pred))
# Out:
# Accuracy: 0.8372093023255814
#               precision    recall  f1-score   support
#
#            1       0.85      0.94      0.89        31
#            2       0.78      0.58      0.67        12
#
#     accuracy                           0.84        43
#    macro avg       0.82      0.76      0.78        43
# weighted avg       0.83      0.84      0.83        43

# %%
y_train_pred = rf.predict(X_train)
print("Accuracy:" , accuracy_score(y_train, y_train_pred))
# Out:
# Accuracy: 0.936046511627907

# %%
pickle. dump(rf, open("rf_job_placement.pickle", "wb"))

# %%
knn = KNeighborsClassifier(n_neighbors=4)
knn.fit(X_train, y_train)
y_test_pred = knn.predict(X_test)
print("Accuracy:" , accuracy_score(y_test, y_test_pred))
print(classification_report(y_test, y_test_pred))
# Out:
# Accuracy: 0.8837209302325582
#               precision    recall  f1-score   support
#
#            1       0.86      1.00      0.93        31
#            2       1.00      0.58      0.74        12
#
#     accuracy                           0.88        43
#    macro avg       0.93      0.79      0.83        43
# weighted avg       0.90      0.88      0.87        43

# %%
y_train_pred = knn.predict(X_train)
print("Accuracy:" , accuracy_score(y_train, y_train_pred))
# Out:
# Accuracy: 0.872093023255814

# %%
import pickle

# %%
pickle. dump(lr,open("job_placement_lr.pickle", "wb"))

# %%
import numpy as np
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.layers import ReLU
from tensorflow.keras.layers import Dropout

# %%
# Define the model architecture
model = Sequential()
model.add(Dense(64, activation='relu', input_dim=X_train.shape[1]))
model.add(Dense(32, activation='relu'))
model.add(Dense(1, activation='sigmoid'))

# %%
# Compile the model
model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])

# Train the model
model.fit(X_train, y_train, epochs=200, batch_size=4, validation_data=(X, y))

# Evaluate the model on the test set
test_loss, test_acc = model.evaluate(X_test, y_test)
print('Test accuracy:', test_acc)
# Out:
# Epoch 1/200
# 43/43 [==============================] - 1s 7ms/step - loss: -18.3864 - accuracy: 0.6802 - val_loss: -41.0103 - val_accuracy: 0.6884
# Epoch 2/200
# 43/43 [==============================] - 0s 3ms/step - loss: -79.8253 - accuracy: 0.6802 - val_loss: -132.2393 - val_accuracy: 0.6884
# Epoch 3/200
# 43/43 [==============================] - 0s 3ms/step - loss: -228.2879 - accuracy: 0.6802 - val_loss: -354.0337 - val_accuracy: 0.6884
# Epoch 4/200
# 43/43 [==============================] - 0s 3ms/step - loss: -550.1855 - accuracy: 0.6802 - val_loss: -782.4048 - val_accuracy: 0.6884
# Epoch 5/200
# 43/43 [==============================] - 0s 3ms/step - loss: -1134.5194 - accuracy: 0.6802 - val_loss: -1473.7439 - val_accuracy: 0.6884
# Epoch 6/200
# 43/43 [==============================] - 0s 3ms/step - loss: -2087.0427 - accuracy: 0.6802 - val_loss: -2623.1218 - val_accuracy: 0.6884
# Epoch 7/200
# ...

# %%
train_loss, train_acc = model.evaluate(X_train, y_train)
print('Test accuracy:', train_acc)
# Out:
# 6/6 [==============================] - 0s 2ms/step - loss: -42660388.0000 - accuracy: 0.6802
# Test accuracy: 0.680232584476471
